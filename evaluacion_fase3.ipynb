# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
pd.set_option('display.max_columns', None)  #para ver todas las columnas del df

# %%
df_visualizacion = df_flight= pd.read_csv("files/df_clean.csv")
df_flight.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %% [markdown]
# FASE 3 VISUALIZACION

# %% [markdown]
# . ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?
#
# #he probado varios y no me sale

# %%
sns.barplot(data= df_visualizacion, x="Flights Booked", y="Year", errorbar=None)
# Out:
# <Axes: xlabel='Flights Booked', ylabel='Year'>

# %%
sns.scatterplot(data=df_visualizacion, x="Flights Booked", y="Year");

# %% [markdown]
# ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente?

# %% [markdown]
# #se puede ver que a mayor distancia de los vuelos mayor son los puntos acumulados

# %%
sns.scatterplot(data=df_visualizacion, x="Distance", y="Points Accumulated", alpha=0.5)
# Out:
# <Axes: xlabel='Distance', ylabel='Points Accumulated'>

# %% [markdown]
# ¿Cuál es la distribución de los clientes por provincia o estado?

# %% [markdown]
# #tenemos muchos mas clientes que son de ontairo, britis... de provincias mas grandes

# %%
sns.countplot(data=df_visualizacion, x="Province", order=df_visualizacion["Province"].value_counts().index)
plt.xticks(rotation=45)
plt.title(" Clientes por Provincia")
plt.show()

# %% [markdown]
# ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?

# %% [markdown]
# #el salario depende de la educacion pero claramente destaca el nivel educativo mas alto que es el de doctor seguido del master el resto se mantiene en la media

# %%
sns.barplot(data= df_visualizacion, x="Education", y="Salary", errorbar=None)
# Out:
# <Axes: xlabel='Education', ylabel='Salary'>

# %% [markdown]
#  ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?

# %% [markdown]
# #la Star es la que mas clientes tienen es un poco menos de la mitad de los 3 tipos de tarjeta

# %%
conteo_tarjetas = df_visualizacion["Loyalty Card"].value_counts()  #tengo  que crear esta variable ya que es texto y el quesito no lo admite
plt.pie(conteo_tarjetas, 
        labels=conteo_tarjetas.index, # Los nombres de las tarjetas
        autopct='%1.1f%%');

# %% [markdown]
# ¿Cómo se distribuyen los clientes según su estado civil y género?

# %% [markdown]
# #se distribuyen al mismo nivel segun su estado civil. hay mismos hombres y mujeres casados y lo mismo pasa con solteros y divorciados. Estan a la par los géneros

# %%
sns.countplot(data=df_visualizacion, x="Marital Status", hue="Gender")
# Out:
# <Axes: xlabel='Marital Status', ylabel='count'>
